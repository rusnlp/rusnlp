# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pylab as plot
from pickle import load

# %%
with open('/Users/defeater/Downloads/dialog_confs_by_year.pickle', 'rb') as f:
    s = load(f)

# %%
s
# Out:
# [(79,
#   'Словарный Подход к Разрешению Омонимии при Выделении Именованных Сущностей в Русском Языке (Dictionary-based Ambiguity Resolution in Russian Named Entities Recognition. a Case Study)',
#   2013),
#  (82,
#   'Автоматическое Достраивание Таксономии на Русском Языке на Основе Ресурсов Википедии',
#   2013),
#  (83,
#   'Combining Hmm and Unit Selection Technologies  to Increase Naturalness of Synthesized Speech',
#   2013),
#  (85,
#   'Как Моделировать Понимание Естественного Языка: Формальное Представление Смысла',
#   2013),
#  (88, 'Тестирование Правил для Системы Анализа Тональности', 2013),
#  (89,
#   'Описание Русских Конструкций с Внешним Посессором в Системе Автоматической Обработки Естественного Языка',
#   2013),
#  (94,
#   'Незавершенность Предложения Vs. Незавершенность Текста: Акценты и Акцентоносители',
#   2013),
#  (95, 'Using Basic Syntactic Relations for Sentiment Analysis', 2013),
#  (97,
# ...

# %%
d = [[(2000, 'en', 3), (2000, 'ru', 112)],
[(2001, 'en', 3), (2001, 'ru', 96)],
[(2003, 'en', 7), (2003, 'ru', 147)],
[(2004, 'en', 7), (2004, 'ru', 109)],
[(2005, 'en', 4), (2005, 'ru', 116)],
[(2006, 'en', 3), (2006, 'ru', 123)],
[(2007, 'en', 2), (2007, 'ru', 98)],
[(2008, 'en', 3), (2008, 'ru', 94)],
[(2009, 'en', 5), (2009, 'ru', 91)],
[(2010, 'en', 7), (2010, 'ru', 91)],
[(2011, 'en', 27), (2011, 'ru', 46)],
[(2012, 'en', 32), (2012, 'ru', 56)],
[(2013, 'en', 38), (2013, 'ru', 52)],
[(2014, 'en', 34), (2014, 'ru', 31)],
[(2015, 'en', 43), (2015, 'ru', 44)],
[(2016, 'en', 48), (2016, 'ru', 52)],
[(2017, 'en', 37), (2017, 'ru', 62)]]

# %%
params = {'legend.fontsize': 20,
          'legend.handlelength': 2}
plot.rcParams.update(params)

# %%
sns.set_style('white')

N = 11
men_means = [i[0][2] for i in d[6:]]

ind = np.arange(N)  # the x locations for the groups
width = 0.35       # the width of the bars

fig, ax = plt.subplots()
fig.set_figheight(15)
fig.set_figwidth(15)
rects1 = ax.bar(ind, men_means, width, color='r')

women_means = [i[1][2] for i in d[6:]]
rects2 = ax.bar(ind + width, women_means, width, color='y')

# add some text for labels, title and axes ticks
ax.set_ylabel('Amount', fontsize=20)
#ax.set_title('Amount of ', fontsize=20)
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(('2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017'), fontsize=14)
#ax.set_yticks(fontsize=14)

ax.legend((rects1[0], rects2[0]), ('English', 'Russian'))


def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.01*height,
                '%d' % int(height),
                ha='center', va='bottom', fontsize=20)

autolabel(rects1)
autolabel(rects2)
plt.tick_params(which='both', labelsize=20)

#plt.show()
plt.savefig('papers.png', bbox_inches='tight')

# %%
[('Dialog', 100)]
[('Dialog', 97), ('RuSSIR', 8)]
[('Dialog', 96), ('RuSSIR', 1)]
[('Dialog', 98), ('RuSSIR', 2)]
[('Dialog', 73), ('RuSSIR', 4)]
[('AIST', 10), ('Dialog', 88), ('RuSSIR', 5)]
[('AIST', 11), ('Dialog', 90), ('RuSSIR', 6)]
[('AIST', 14), ('Dialog', 65), ('RuSSIR', 5)]
[('AINL', 30), ('AIST', 8), ('Dialog', 87), ('RuSSIR', 4)]
[('AINL', 24), ('AIST', 12), ('Dialog', 100)]
[('AINL', 23), ('AIST', 11), ('Dialog', 99)]

# %%
x = [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017]

plt.figure(figsize=(18, 8))
plt.xticks(x)
# plt.rc('font',**{'family':'serif','serif':['Times']})
plt.tick_params(labelsize=20)
#fig, ax = plt.subplots()

line1 = plt.plot(x, [0, 0, 0, 0, 0, 10, 11, 14, 8, 12, 11], 
                 label='AIST', linewidth=4, marker='^', markersize=15)
#line1.set_dashes(dashes)

line2 = plt.plot(x, [0, 0, 0, 0, 0, 0, 0, 0, 34, 24, 23], 
                 label='AINL', linewidth=4, marker='o', markersize=15)

line3 = plt.plot(x, [100, 97, 96, 98, 73, 88, 90, 65, 87, 100, 99],
                 label='Dialogue', linewidth=4, marker='<', markersize=15)


plt.grid(True, axis='y', linewidth=1, color='grey')

#plt.legend(loc='best', bbox_to_anchor=(1,1), prop={'size':20})
leg = plt.legend(loc='best', prop={'size':30}, frameon=True)
leg.get_frame().set_linewidth(3)
leg.get_frame().set_edgecolor('black')

#plt.title("DUMMY PLOT", size=30)
#plt.show()
plt.savefig('distribution.png', bbox_inches='tight')

# %%
sns.set_style('white')

N = 6
men_means = [88, 90, 65, 87, 100, 99]

ind = np.arange(N)  # the x locations for the groups
width = 0.2       # the width of the bars

fig, ax = plt.subplots()
fig.set_figheight(15)
fig.set_figwidth(15)
rects1 = ax.bar(ind, men_means, width, color='r')

women_means = [10, 11, 14, 8, 12, 11]
rects2 = ax.bar(ind + width, women_means, width, color='y')

kea_means = [0, 0, 0, 30, 24, 23]
rects3 = ax.bar(ind + width*2, kea_means, width, color='green')

# add some text for labels, title and axes ticks
ax.set_ylabel('Amount', fontsize=20)
#ax.set_title('Amount of ', fontsize=20)
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(('2012', '2013', '2014', '2015', '2016', '2017'), fontsize=14)
#ax.set_yticks(fontsize=14)

ax.legend((rects1[0], rects2[0], rects3[1]), ('Dialogue', 'AIST', 'AINL'))


def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.01*height,
                '%d' % int(height),
                ha='center', va='bottom', fontsize=20)

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)

plt.tick_params(which='both', labelsize=20)
plt.show()
#plt.savefig('distr.png', bbox_inches='tight')

# %%
topics_years = {2016:[('russian', 2), ('distributional semantics', 2), ('aes', 1), ('low resource', 1), ('word2vec', 1)],
2017:[('word embeddings', 4), ('paraphrase detection', 3), ('information retrieval', 2), ('natural language processing', 2), ('synset induction', 2)],
2015:[('russian', 9), ('corpus linguistics', 5), ('semantics', 5), ('semantic similarity', 4), ('corpus', 4)]}

# %%
colors = ['red', 'blue', 'green']

# %%
plt.figure(figsize=(20, 30))

counter = 1
max_in_topics = max([topic[1] for topic in topics for topics in topics_years.values()])

for year, topics in topics_years.items():
    plt.subplot(len(topics_years.keys()), 1, counter)
    plt.xlim([0.0, max_in_topics])
    plt.title(str(year), size=30)
    topics_names = [topic[0] for topic in topics]
    topics_counts = [topic[1] for topic in topics]
    plt.barh(topics_names, topics_counts, align='center', color=colors[counter-1], ecolor='black')
    plt.yticks(np.arange(len(topics)))
    plt.tick_params(labelsize=30)
    counter += 1

plt.legend(loc='best')

plt.tight_layout()
plt.show()
#plt.savefig('dummy2.png')
